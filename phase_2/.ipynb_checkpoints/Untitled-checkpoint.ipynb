# %%
import os
import rasterio
from rasterio.warp import calculate_default_transform, reproject, Resampling

# Input and output directories
input_dir = "./tiffs"
output_dir = "./tiffs_reprojected"

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Target CRS (WGS 1984 UTM Zone 40N)
target_crs = "EPSG:32640"

# Loop through all TIFF files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith(".tif") or filename.endswith(".tiff"):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)

        print(f"Reprojecting {filename}...")

        # Open the input TIFF
        with rasterio.open(input_path) as src:
            # Calculate transformation for the target CRS
            transform, width, height = calculate_default_transform(
                src.crs, target_crs, src.width, src.height, *src.bounds
            )

            # Set up metadata for the output file
            kwargs = src.meta.copy()
            kwargs.update({
                'crs': target_crs,
                'transform': transform,
                'width': width,
                'height': height
            })

            # Create the output TIFF and perform reprojection
            with rasterio.open(output_path, 'w', **kwargs) as dst:
                for i in range(1, src.count + 1):  # Loop through bands
                    reproject(
                        source=rasterio.band(src, i),
                        destination=rasterio.band(dst, i),
                        src_transform=src.transform,
                        src_crs=src.crs,
                        dst_transform=transform,
                        dst_crs=target_crs,
                        resampling=Resampling.bilinear  # Change to Resampling.nearest for categorical data
                    )

        print(f"Saved reprojected file to {output_path}")

print("Reprojection complete!")
# Out:
# Reprojecting 20230403.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230403.ti.geo.tif
# Reprojecting 20230415.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230415.ti.geo.tif
# Reprojecting 20230427.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230427.ti.geo.tif
# Reprojecting 20230509.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230509.ti.geo.tif
# Reprojecting 20230521.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230521.ti.geo.tif
# Reprojecting 20230602.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230602.ti.geo.tif
# Reprojecting 20230614.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230614.ti.geo.tif
# Reprojecting 20230626.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230626.ti.geo.tif
# Reprojecting 20230708.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230708.ti.geo.tif
# Reprojecting 20230720.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230720.ti.geo.tif
# Reprojecting 20230801.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230801.ti.geo.tif
# Reprojecting 20230813.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230813.ti.geo.tif
# Reprojecting 20230825.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230825.ti.geo.tif
# Reprojecting 20230906.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230906.ti.geo.tif
# Reprojecting 20230918.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230918.ti.geo.tif
# Reprojecting 20230930.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230930.ti.geo.tif
# Reprojecting 20231012.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20231012.ti.geo.tif
# Reprojecting 20231024.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20231024.ti.geo.tif
# Reprojecting 20231105.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20231105.ti.geo.tif
# Reprojecting 20231117.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20231117.ti.geo.tif
# Reprojecting 20231129.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20231129.ti.geo.tif
# Reprojecting 20231211.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20231211.ti.geo.tif
# Reprojecting 20231223.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20231223.ti.geo.tif
# Reprojecting 20240104.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20240104.ti.geo.tif
# Reprojecting 20240116.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20240116.ti.geo.tif
# Reprojecting 20240209.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20240209.ti.geo.tif
# Reprojecting 20240221.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20240221.ti.geo.tif
# Reprojecting 20150220.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20150220.ti.geo.tif
# Reprojecting 20150304.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20150304.ti.geo.tif
# Reprojecting 20150328.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20150328.ti.geo.tif
# Reprojecting 20150421.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20150421.ti.geo.tif
# Reprojecting 20150515.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20150515.ti.geo.tif
# Reprojecting 20150702.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20150702.ti.geo.tif
# Reprojecting 20150726.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20150726.ti.geo.tif
# Reprojecting 20150819.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20150819.ti.geo.tif
# Reprojecting 20151030.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20151030.ti.geo.tif
# Reprojecting 20151123.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20151123.ti.geo.tif
# Reprojecting 20151217.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20151217.ti.geo.tif
# Reprojecting 20160110.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160110.ti.geo.tif
# Reprojecting 20160203.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160203.ti.geo.tif
# Reprojecting 20160227.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160227.ti.geo.tif
# Reprojecting 20160322.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160322.ti.geo.tif
# Reprojecting 20160415.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160415.ti.geo.tif
# Reprojecting 20160602.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160602.ti.geo.tif
# Reprojecting 20160720.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160720.ti.geo.tif
# Reprojecting 20160813.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160813.ti.geo.tif
# Reprojecting 20160906.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160906.ti.geo.tif
# Reprojecting 20160930.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160930.ti.geo.tif
# Reprojecting 20161024.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20161024.ti.geo.tif
# Reprojecting 20161117.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20161117.ti.geo.tif
# Reprojecting 20161211.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20161211.ti.geo.tif
# Reprojecting 20170104.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170104.ti.geo.tif
# Reprojecting 20170128.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170128.ti.geo.tif
# Reprojecting 20170209.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170209.ti.geo.tif
# Reprojecting 20170221.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170221.ti.geo.tif
# Reprojecting 20170305.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170305.ti.geo.tif
# Reprojecting 20170317.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170317.ti.geo.tif
# Reprojecting 20170329.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170329.ti.geo.tif
# Reprojecting 20170410.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170410.ti.geo.tif
# Reprojecting 20170504.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170504.ti.geo.tif
# Reprojecting 20170516.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170516.ti.geo.tif
# Reprojecting 20170528.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170528.ti.geo.tif
# Reprojecting 20170609.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170609.ti.geo.tif
# Reprojecting 20170703.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170703.ti.geo.tif
# Reprojecting 20170715.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170715.ti.geo.tif
# Reprojecting 20170727.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170727.ti.geo.tif
# Reprojecting 20170808.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170808.ti.geo.tif
# Reprojecting 20170820.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170820.ti.geo.tif
# Reprojecting 20170901.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170901.ti.geo.tif
# Reprojecting 20170913.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170913.ti.geo.tif
# Reprojecting 20170925.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170925.ti.geo.tif
# Reprojecting 20171007.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20171007.ti.geo.tif
# Reprojecting 20171019.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20171019.ti.geo.tif
# Reprojecting 20171031.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20171031.ti.geo.tif
# Reprojecting 20171112.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20171112.ti.geo.tif
# Reprojecting 20171206.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20171206.ti.geo.tif
# Reprojecting 20171218.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20171218.ti.geo.tif
# Reprojecting 20171230.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20171230.ti.geo.tif
# Reprojecting 20180111.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180111.ti.geo.tif
# Reprojecting 20180123.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180123.ti.geo.tif
# Reprojecting 20180204.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180204.ti.geo.tif
# Reprojecting 20180216.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180216.ti.geo.tif
# Reprojecting 20180228.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180228.ti.geo.tif
# Reprojecting 20180312.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180312.ti.geo.tif
# Reprojecting 20180324.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180324.ti.geo.tif
# Reprojecting 20180405.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180405.ti.geo.tif
# Reprojecting 20180417.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180417.ti.geo.tif
# Reprojecting 20180429.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180429.ti.geo.tif
# Reprojecting 20180511.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180511.ti.geo.tif
# Reprojecting 20180523.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180523.ti.geo.tif
# Reprojecting 20180604.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180604.ti.geo.tif
# Reprojecting 20160509.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20160509.ti.geo.tif
# Reprojecting 20170422.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20170422.ti.geo.tif
# Reprojecting 20171124.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20171124.ti.geo.tif
# Reprojecting 20180616.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180616.ti.geo.tif
# Reprojecting 20190118.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190118.ti.geo.tif
# Reprojecting 20190822.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190822.ti.geo.tif
# Reprojecting 20200406.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200406.ti.geo.tif
# Reprojecting 20201108.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20201108.ti.geo.tif
# Reprojecting 20210624.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210624.ti.geo.tif
# Reprojecting 20220114.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220114.ti.geo.tif
# Reprojecting 20220806.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220806.ti.geo.tif
# Reprojecting 20230322.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230322.ti.geo.tif
# Reprojecting 20180628.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180628.ti.geo.tif
# Reprojecting 20180710.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180710.ti.geo.tif
# Reprojecting 20180722.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180722.ti.geo.tif
# Reprojecting 20180803.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180803.ti.geo.tif
# Reprojecting 20180815.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180815.ti.geo.tif
# Reprojecting 20180827.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180827.ti.geo.tif
# Reprojecting 20180908.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20180908.ti.geo.tif
# Reprojecting 20181002.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20181002.ti.geo.tif
# Reprojecting 20181014.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20181014.ti.geo.tif
# Reprojecting 20181026.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20181026.ti.geo.tif
# Reprojecting 20181107.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20181107.ti.geo.tif
# Reprojecting 20181119.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20181119.ti.geo.tif
# Reprojecting 20181201.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20181201.ti.geo.tif
# Reprojecting 20181213.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20181213.ti.geo.tif
# Reprojecting 20181225.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20181225.ti.geo.tif
# Reprojecting 20190106.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190106.ti.geo.tif
# Reprojecting 20190130.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190130.ti.geo.tif
# Reprojecting 20190211.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190211.ti.geo.tif
# Reprojecting 20190223.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190223.ti.geo.tif
# Reprojecting 20190307.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190307.ti.geo.tif
# Reprojecting 20190331.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190331.ti.geo.tif
# Reprojecting 20190412.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190412.ti.geo.tif
# Reprojecting 20190424.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190424.ti.geo.tif
# Reprojecting 20190506.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190506.ti.geo.tif
# Reprojecting 20190518.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190518.ti.geo.tif
# Reprojecting 20190530.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190530.ti.geo.tif
# Reprojecting 20190611.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190611.ti.geo.tif
# Reprojecting 20190623.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190623.ti.geo.tif
# Reprojecting 20190705.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190705.ti.geo.tif
# Reprojecting 20190717.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190717.ti.geo.tif
# Reprojecting 20190729.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190729.ti.geo.tif
# Reprojecting 20190810.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190810.ti.geo.tif
# Reprojecting 20190903.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190903.ti.geo.tif
# Reprojecting 20190915.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190915.ti.geo.tif
# Reprojecting 20190927.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20190927.ti.geo.tif
# Reprojecting 20191009.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20191009.ti.geo.tif
# Reprojecting 20191021.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20191021.ti.geo.tif
# Reprojecting 20191102.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20191102.ti.geo.tif
# Reprojecting 20191114.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20191114.ti.geo.tif
# Reprojecting 20191126.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20191126.ti.geo.tif
# Reprojecting 20191208.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20191208.ti.geo.tif
# Reprojecting 20191220.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20191220.ti.geo.tif
# Reprojecting 20200101.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200101.ti.geo.tif
# Reprojecting 20200125.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200125.ti.geo.tif
# Reprojecting 20200206.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200206.ti.geo.tif
# Reprojecting 20200218.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200218.ti.geo.tif
# Reprojecting 20200301.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200301.ti.geo.tif
# Reprojecting 20200313.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200313.ti.geo.tif
# Reprojecting 20200418.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200418.ti.geo.tif
# Reprojecting 20200430.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200430.ti.geo.tif
# Reprojecting 20200512.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200512.ti.geo.tif
# Reprojecting 20200524.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200524.ti.geo.tif
# Reprojecting 20200605.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200605.ti.geo.tif
# Reprojecting 20200617.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200617.ti.geo.tif
# Reprojecting 20200629.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200629.ti.geo.tif
# Reprojecting 20200723.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200723.ti.geo.tif
# Reprojecting 20200804.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200804.ti.geo.tif
# Reprojecting 20200816.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200816.ti.geo.tif
# Reprojecting 20200828.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200828.ti.geo.tif
# Reprojecting 20200909.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200909.ti.geo.tif
# Reprojecting 20200921.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20200921.ti.geo.tif
# Reprojecting 20201003.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20201003.ti.geo.tif
# Reprojecting 20201015.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20201015.ti.geo.tif
# Reprojecting 20201027.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20201027.ti.geo.tif
# Reprojecting 20201120.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20201120.ti.geo.tif
# Reprojecting 20201202.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20201202.ti.geo.tif
# Reprojecting 20201214.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20201214.ti.geo.tif
# Reprojecting 20210107.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210107.ti.geo.tif
# Reprojecting 20210119.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210119.ti.geo.tif
# Reprojecting 20210131.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210131.ti.geo.tif
# Reprojecting 20210212.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210212.ti.geo.tif
# Reprojecting 20210224.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210224.ti.geo.tif
# Reprojecting 20210308.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210308.ti.geo.tif
# Reprojecting 20210320.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210320.ti.geo.tif
# Reprojecting 20210413.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210413.ti.geo.tif
# Reprojecting 20210425.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210425.ti.geo.tif
# Reprojecting 20210507.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210507.ti.geo.tif
# Reprojecting 20210519.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210519.ti.geo.tif
# Reprojecting 20210531.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210531.ti.geo.tif
# Reprojecting 20210612.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210612.ti.geo.tif
# Reprojecting 20210706.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210706.ti.geo.tif
# Reprojecting 20210718.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210718.ti.geo.tif
# Reprojecting 20210730.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210730.ti.geo.tif
# Reprojecting 20210811.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210811.ti.geo.tif
# Reprojecting 20210823.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210823.ti.geo.tif
# Reprojecting 20210904.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210904.ti.geo.tif
# Reprojecting 20210916.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210916.ti.geo.tif
# Reprojecting 20210928.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20210928.ti.geo.tif
# Reprojecting 20211010.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20211010.ti.geo.tif
# Reprojecting 20211022.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20211022.ti.geo.tif
# Reprojecting 20211103.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20211103.ti.geo.tif
# Reprojecting 20211115.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20211115.ti.geo.tif
# Reprojecting 20211127.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20211127.ti.geo.tif
# Reprojecting 20211209.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20211209.ti.geo.tif
# Reprojecting 20211221.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20211221.ti.geo.tif
# Reprojecting 20220102.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220102.ti.geo.tif
# Reprojecting 20220126.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220126.ti.geo.tif
# Reprojecting 20220207.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220207.ti.geo.tif
# Reprojecting 20220219.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220219.ti.geo.tif
# Reprojecting 20220303.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220303.ti.geo.tif
# Reprojecting 20220315.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220315.ti.geo.tif
# Reprojecting 20220327.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220327.ti.geo.tif
# Reprojecting 20220408.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220408.ti.geo.tif
# Reprojecting 20220420.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220420.ti.geo.tif
# Reprojecting 20220502.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220502.ti.geo.tif
# Reprojecting 20220514.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220514.ti.geo.tif
# Reprojecting 20220526.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220526.ti.geo.tif
# Reprojecting 20220607.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220607.ti.geo.tif
# Reprojecting 20220619.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220619.ti.geo.tif
# Reprojecting 20220701.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220701.ti.geo.tif
# Reprojecting 20220713.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220713.ti.geo.tif
# Reprojecting 20220725.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220725.ti.geo.tif
# Reprojecting 20220818.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220818.ti.geo.tif
# Reprojecting 20220830.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220830.ti.geo.tif
# Reprojecting 20220911.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220911.ti.geo.tif
# Reprojecting 20220923.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20220923.ti.geo.tif
# Reprojecting 20221005.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20221005.ti.geo.tif
# Reprojecting 20221029.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20221029.ti.geo.tif
# Reprojecting 20221110.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20221110.ti.geo.tif
# Reprojecting 20221122.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20221122.ti.geo.tif
# Reprojecting 20221204.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20221204.ti.geo.tif
# Reprojecting 20221216.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20221216.ti.geo.tif
# Reprojecting 20221228.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20221228.ti.geo.tif
# Reprojecting 20230109.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230109.ti.geo.tif
# Reprojecting 20230121.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230121.ti.geo.tif
# Reprojecting 20230202.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230202.ti.geo.tif
# Reprojecting 20230226.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230226.ti.geo.tif
# Reprojecting 20230310.ti.geo.tif...
# Saved reprojected file to ./tiffs_reprojected/20230310.ti.geo.tif
# Reprojection complete!

# %%
import geopandas as gpd
import rasterio
import numpy as np
from shapely.geometry import Point
import os
import pandas as pd

# Paths
shp_path = "./metro/خط مترو.shp"
raster_dir = "./tiffs_reprojected"
output_path = "./subsidence_profile.csv"

# Step 1: Read the shapefile
gdf = gpd.read_file(shp_path)
line = gdf.geometry.iloc[0]  # Assuming the shapefile contains a single line

# Step 2: Generate points along the line at ~101m intervals
line_length = line.length
distances = np.arange(0, line_length, 101)  # 101m intervals
points = [line.interpolate(distance) for distance in distances]

# Step 3: List all raster files
raster_files = [f for f in os.listdir(raster_dir) if f.endswith(".ti.geo.tif")]
raster_files.sort()  # Sort by date

# Step 4: Extract raster values for each point
results = {"distance_from_start": distances}
for raster_file in raster_files:
    date = raster_file.split(".")[0]  # Extract date (e.g., 20150220)
    with rasterio.open(os.path.join(raster_dir, raster_file)) as src:
        values = []
        for point in points:
            # Get raster value at point
            x, y = point.x, point.y
            try:
                value = next(src.sample([(x, y)]))[0]
                values.append(value if not np.isnan(value) else np.nan)
            except:
                values.append(np.nan)  # Handle cases where point is outside raster
        results[f"val_{date}"] = values

# Step 5: Create a DataFrame and save to CSV
df = pd.DataFrame(results)
df.to_csv(output_path, index=False)
print(f"Output saved to {output_path}")
# Out:
# Output saved to ./subsidence_profile.csv

# %%
import matplotlib.pyplot as plt

# Plot subsidence profiles
for column in df.columns:
    if column.startswith("val_"):
        plt.plot(df["distance_from_start"], df[column], label=column)
plt.xlabel("Distance from Start (m)")
plt.ylabel("Subsidence (m)")
plt.legend()
plt.title("Land Subsidence Along Railroad")
plt.show()

# %%
import geopandas as gpd
import rasterio
import numpy as np
from shapely.geometry import Point
import os
import pandas as pd

# Paths
shp_path = "./metro/خط مترو.shp"
raster_dir = "./tiffs_reprojected"
output_path = "./subsidence_profile_with_xy.csv"

# Step 1: Read the shapefile
gdf = gpd.read_file(shp_path)
line = gdf.geometry.iloc[0]  # Assuming the shapefile contains a single line

# Verify CRS
print(f"Shapefile CRS: {gdf.crs}")
if not gdf.crs.is_projected:
    raise ValueError("Shapefile CRS is not projected (UTM). Please reproject to UTM.")

# Step 2: Get start and end points
start_point = line.coords[0]  # First vertex
end_point = line.coords[-1]   # Last vertex
print(f"Start Point (X, Y in UTM): {start_point}")
print(f"End Point (X, Y in UTM): {end_point}")

# Step 3: Generate points along the line at ~101m intervals
line_length = line.length
distances = np.arange(0, line_length, 101)  # 101m intervals
points = [line.interpolate(distance) for distance in distances]

# Step 4: Extract X, Y coordinates for each point
x_coords = [point.x for point in points]
y_coords = [point.y for point in points]

# Step 5: List all raster files
raster_files = [f for f in os.listdir(raster_dir) if f.endswith(".ti.geo.tif")]
raster_files.sort()  # Sort by date

# Step 6: Extract raster values for each point
results = {
    "distance_from_start": distances,
    "X_UTM": x_coords,
    "Y_UTM": y_coords
}
for raster_file in raster_files:
    date = raster_file.split(".")[0]  # Extract date (e.g., 20150220)
    with rasterio.open(os.path.join(raster_dir, raster_file)) as src:
        values = []
        for point in points:
            # Get raster value at point
            x, y = point.x, point.y
            try:
                value = next(src.sample([(x, y)]))[0]
                values.append(value if not np.isnan(value) else np.nan)
            except:
                values.append(np.nan)  # Handle cases where point is outside raster
        results[f"val_{date}"] = values

# Step 7: Create a DataFrame and save to CSV
df = pd.DataFrame(results)
df.to_csv(output_path, index=False)
print(f"Output saved to {output_path}")

# Optional: Print first few rows of the DataFrame
print("\nFirst few rows of the output:")
print(df.head())
# Out:
# Shapefile CRS: EPSG:32640
# Start Point (X, Y in UTM): (719349.6602999996, 4024908.5347000007)
# End Point (X, Y in UTM): (690679.8828999996, 4056145.2409000006)
# Output saved to ./subsidence_profile_with_xy.csv
#
# First few rows of the output:
#    distance_from_start          X_UTM         Y_UTM  val_20150220  \
# 0                  0.0  719349.660300  4.024909e+06           0.0
# 1                101.0  719255.141857  4.024944e+06           0.0
# 2                202.0  719160.623414  4.024980e+06           0.0
# 3                303.0  719066.104972  4.025015e+06           0.0
# 4                404.0  718971.586536  4.025051e+06           0.0
#
#    val_20150304  val_20150328  val_20150421  val_20150515  val_20150702  \
# 0     -2.195996     -0.942629      1.503353      0.788563      7.239093
# 1     -2.340330     -1.055412      1.610079      0.499338      7.044411
# 2     -2.376158     -0.982602      1.734737      0.404129      6.990516
# 3     -2.138846     -0.751948      2.370093      0.890689      7.200253
# 4     -1.795333     -0.326765      2.816113      1.175125      7.073453
#
#    val_20150726  ...  val_20231024  val_20231105  val_20231117  val_20231129  \
# 0      5.660024  ...     23.937714     23.213577     23.068441     20.962477
# 1      5.508366  ...     24.597958     24.049416     23.517166     21.684347
# 2      5.691042  ...     25.109194     24.664869     23.925964     22.157518
# 3      6.117593  ...     25.527954     24.982288     24.134869     22.680092
# 4      6.311498  ...     25.731926     25.481297     24.282160     23.304224
#
#    val_20231211  val_20231223  val_20240104  val_20240116  val_20240209  \
# 0     22.200066     23.288916     23.538727     24.654085     22.167587
# 1     22.787138     24.144232     24.212200     25.315641     23.087753
# 2     23.129709     24.708513     24.739697     25.813513     23.761919
# 3     23.277302     25.258526     25.088026     26.223850     24.369982
# 4     23.649593     25.850725     25.493378     26.596518     25.005726
#
#    val_20240221
# 0     22.997459
# 1     23.952599
# 2     24.570765
# 3     25.124325
# 4     25.851065
#
# [5 rows x 234 columns]

# %%
import matplotlib.pyplot as plt

# Plot the line and sampled points
plt.plot(*line.xy, label="Railroad Line", color="blue")
x_coords = [p.x for p in points]
y_coords = [point.y for point in points]
plt.scatter(x_coords, y_coords, color="green", label="Sampled Points", s=30)
plt.xlabel("X (UTM, m)")
plt.ylabel("Y (UTM, m)")
plt.legend()
plt.title("Sampled Points Along Railroad")
plt.axis("equal")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Path to the CSV file generated previously
csv_path = "./subsidence_profile_with_xy.csv"

# Read the CSV file
df = pd.read_csv(csv_path)

# Check if the specified column exists
target_date = "val_20240221"
if target_date not in df.columns:
    print(f"Error: Column '{target_date}' not found in the CSV. Available columns: {list(df.columns)}")
    print("Please specify a valid date column (e.g., 'val_20210823').")
else:
    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(df["distance_from_start"], df[target_date], label=target_date, color="blue", marker="o", markersize=4)
    plt.xlabel("Distance from Start (m)")
    plt.ylabel("Subsidence (m)")
    plt.title("Land Subsidence Along Railroad on 2024-02-21")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import LineString

# Paths
shp_path = "./metro/خط مترو.shp"
csv_path = "./subsidence_profile_with_xy.csv"

# Read the shapefile and CSV
gdf = gpd.read_file(shp_path)
df = pd.read_csv(csv_path)
line = gdf.geometry.iloc[0]  # Assuming single line

# Target date for subsidence profile (replace with correct date if needed)
target_date = "val_20210823"
if target_date not in df.columns:
    print(f"Error: Column '{target_date}' not found. Available columns: {list(df.columns)}")
    raise ValueError("Please specify a valid date column (e.g., 'val_20210823').")

# Create figure with two subplots (vertically stacked)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), gridspec_kw={'height_ratios': [1, 1]})

# Top plot: Railroad line in UTM
# Plot the line
x_line, y_line = line.xy
ax1.plot(x_line, y_line, color="blue", linewidth=2, label="Railroad Line")
# Plot sampled points
ax1.scatter(df["X_UTM"], df["Y_UTM"], color="red", s=10, label="Sampled Points")
ax1.set_xlabel("X (UTM, m)")
ax1.set_ylabel("Y (UTM, m)")
ax1.set_title("Railroad Line in UTM Coordinates")
ax1.legend()
ax1.axis("equal")  # Equal scaling for X and Y
ax1.grid(True)

# Bottom plot: Subsidence profile
ax2.plot(df["distance_from_start"], df[target_date], color="green", marker="o", markersize=4, label=target_date)
ax2.set_xlabel("Distance from Start (m)")
ax2.set_ylabel("Subsidence (m)")
ax2.set_title(f"Subsidence Profile Along Railroad on {target_date.replace('val_', '')}")
ax2.legend()
ax2.grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show plot
plt.show()

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import LineString

# Paths
shp_path = "./metro/خط مترو.shp"
csv_path = "./subsidence_profile_with_xy.csv"

# Read the shapefile and CSV
gdf = gpd.read_file(shp_path)
df = pd.read_csv(csv_path)
line = gdf.geometry.iloc[0]  # Assuming single line

# Target date for subsidence profile (replace with correct date if needed)
target_date = "val_20210823"
if target_date not in df.columns:
    print(f"Error: Column '{target_date}' not found. Available columns: {list(df.columns)}")
    raise ValueError("Please specify a valid date column (e.g., 'val_20210823').")

# Create figure with two subplots (vertically stacked)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), gridspec_kw={'height_ratios': [1, 1]})

# Top plot: Railroad line in UTM
# Plot the line
x_line, y_line = line.xy
ax1.plot(x_line, y_line, color="blue", linewidth=2, label="Railroad Line")
# Plot sampled points
ax1.scatter(df["X_UTM"], df["Y_UTM"], color="red", s=10, label="Sampled Points")
ax1.set_xlabel("X (UTM, m)")
ax1.set_ylabel("Y (UTM, m)")
ax1.set_title("Railroad Line in UTM Coordinates")
ax1.legend()
ax1.axis("equal")  # Equal scaling for X and Y
ax1.grid(True)

# Bottom plot: Subsidence profile
ax2.plot(df["distance_from_start"], df[target_date], color="green", marker="o", markersize=4, label=target_date)
ax2.set_xlabel("Distance from Start (m)")
ax2.set_ylabel("Subsidence (m)")
ax2.set_title(f"Subsidence Profile Along Railroad on {target_date.replace('val_', '')}")
ax2.legend()
ax2.grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show plot
plt.show()
