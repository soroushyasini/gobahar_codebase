# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]━━ 1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd

# Open the Excel file
df = pd.read_excel('cordinates.xlsx')

# %%
df
# Out:
#                         location            X             Y
# 0             مجتمع آموزشی پرواز  695029.9370  4.053035e+06
# 1      مجتمع آموزشی پرواز(موجود)  695953.2804  4.052398e+06
# 2                 دپوی قطار شهری  693721.0169  4.053096e+06
# 3                    مجموع ورزشی  695874.1969  4.052168e+06
# 4             کانون تجمع و امداد  695265.1365  4.051042e+06
# 5                بیمارستان موجود  695828.3050  4.050435e+06
# 6                        پست برق  694411.6908  4.049937e+06
# 7             کانون تجمع و امداد  693738.8039  4.049644e+06
# 8            آتش‌نشانی و کلانتری  693700.1689  4.049392e+06
# 9                 ورودی اصلی شهر  698219.6850  4.051270e+06
# 10  بخشداری،پاسگاه و پایگاه بسیج  697876.7896  4.050822e+06
# 11                      نمایشگاه  698274.9886  4.050438e+06
# 12                 مجموعه فرهنگی  697605.2455  4.050436e+06
# 13               شورای حل اختلاف  697252.6305  4.049705e+06
# 14                          مسجد  696628.1594  4.049759e+06
# 15                          مسجد  697153.3668  4.049161e+06
# 16                    سالن ورزشی  696207.7307  4.049349e+06
# 17                          مسجد  695786.9164  4.049451e+06
# 18                    آتش‌نشانی   696063.6492  4.050009e+06
# 19                       کلانتری  696082.3877  4.049951e+06
# 20                مصلی(پیشنهادی)  694606.1483  4.048984e+06
# 21                       منبع آب  694201.9695  4.049010e+06
# 22                       منبع آب  692904.3448  4.048445e+06
# 23                       منبع آب  690702.4367  4.048344e+06
# 24                        پایانه  691577.7646  4.047074e+06
# 25                       دانشگاه  692944.0554  4.047732e+06
# 26                  دانشگاه آزاد  692010.4316  4.049623e+06
# 27                    اسکان موقت  690301.8602  4.047174e+06
# 28                    اسکان موقت  692509.7822  4.048808e+06
# 29           بیمارستان(پیشنهادی)  689236.0929  4.047212e+06
# 30    مجموعه های آموزشی و پژوهشی  689773.2101  4.047972e+06
# 31                  مجموعه ورزشی  690063.6845  4.049122e+06
# 32                باغ گیاه شناسی  689035.1816  4.047994e+06
# 33            کانون تجمع و امداد  690704.2154  4.045891e+06
# 34         کانروانسرای حوض حضرتی  692711.6923  4.045384e+06
# 35            کانون تجمع و امداد  692375.2757  4.046950e+06
# 36            کانون تجمع و امداد  694308.1538  4.046617e+06
# 37      بهداشتی-درمانی(پیشنهادی)  694103.4791  4.047709e+06
# 38                    پایانه بار  694032.0414  4.052710e+06
# 39               انبار و سردخانه  693888.4630  4.052246e+06
# 40          میدان میوه و تره بار  694550.4295  4.052300e+06
# 41                مجموعه گردشگری  698224.1922  4.049907e+06
# 42                     بیمارستان  697548.9062  4.050948e+06
# 43    پایانه مسافربری چند منظوره  697292.1941  4.051185e+06
# 44                    پلیس راهور  694860.0000  4.053507e+06
# 45                   جایگاه سوخت  698193.2535  4.050607e+06

# %%
# !pip install pyproj
# Out:
# Collecting pyproj
#   Using cached pyproj-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: certifi in /home/linux/miniconda3/envs/licsbas2/lib/python3.10/site-packages (from pyproj) (2025.4.26)
# Downloading pyproj-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/9.3 MB ? eta -:--:--0m
# WARNING: Connection timed out while downloading.
# error: incomplete-download
#
# × Download failed because not enough bytes were received (0 bytes/9.3 MB)
# ╰─> URL: https://files.pythonhosted.org/packages/76/a5/c6e11b9a99ce146741fb4d184d5c468446c6d6015b183cae82ac822a6cfa/pyproj-3.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
#
# note: This is an issue with network connectivity, not pip.
# hint: Consider using --resume-retries to enable download resumption.

# %%
import pandas as pd
import folium
from pyproj import Transformer

# Read the Excel file
df = pd.read_excel('cordinates.xlsx')

# Create a Transformer for UTM Zone 40 North to WGS84 (lat/lon)
transformer = Transformer.from_crs("EPSG:32640", "EPSG:4326", always_xy=True)

# Function to convert UTM to decimal degrees
def utm_to_latlon(row):
    if pd.isna(row['X']) or pd.isna(row['Y']):  # Handle NaN values
        return pd.Series([None, None], index=['latitude', 'longitude'])
    lon, lat = transformer.transform(row['X'], row['Y'])
    return pd.Series([lat, lon], index=['latitude', 'longitude'])

# Apply conversion to each row
df[['latitude', 'longitude']] = df.apply(utm_to_latlon, axis=1)

# Create a Folium map centered on the average of valid coordinates
valid_coords = df.dropna(subset=['latitude', 'longitude'])
center_lat = valid_coords['latitude'].mean()
center_lon = valid_coords['longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)

# Add markers for each valid location
for _, row in valid_coords.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['location'],
        tooltip=row['location']
    ).add_to(m)

# Save the map to an HTML file
m.save('coordinates_map.html')

# Print the DataFrame to verify coordinates
print(df)

# Inform user about the map
print("Map has been saved as 'coordinates_map.html'. Open it in a web browser to view the locations.")
# Out:
#                         location            X             Y   latitude  \
# 0             مجتمع آموزشی پرواز  695029.9370  4.053035e+06  36.602893
# 1      مجتمع آموزشی پرواز(موجود)  695953.2804  4.052398e+06  36.596963
# 2                 دپوی قطار شهری  693721.0169  4.053096e+06  36.603713
# 3                    مجموع ورزشی  695874.1969  4.052168e+06  36.594907
# 4             کانون تجمع و امداد  695265.1365  4.051042e+06  36.584895
# 5                بیمارستان موجود  695828.3050  4.050435e+06  36.579305
# 6                        پست برق  694411.6908  4.049937e+06  36.575112
# 7             کانون تجمع و امداد  693738.8039  4.049644e+06  36.572605
# 8            آتش‌نشانی و کلانتری  693700.1689  4.049392e+06  36.570350
# 9                 ورودی اصلی شهر  698219.6850  4.051270e+06  36.586336
# 10  بخشداری،پاسگاه و پایگاه بسیج  697876.7896  4.050822e+06  36.582369
# 11                      نمایشگاه  698274.9886  4.050438e+06  36.578830
# 12                 مجموعه فرهنگی  697605.2455  4.050436e+06  36.578951
# 13               شورای حل اختلاف  697252.6305  4.049705e+06  36.572438
# 14                          مسجد  696628.1594  4.049759e+06  36.573057
# 15                          مسجد  697153.3668  4.049161e+06  36.567558
# 16                    سالن ورزشی  696207.7307  4.049349e+06  36.569448
# 17                          مسجد  695786.9164  4.049451e+06  36.570451
# 18                    آتش‌نشانی   696063.6492  4.050009e+06  36.575420
# 19                       کلانتری  696082.3877  4.049951e+06  36.574900
# 20                مصلی(پیشنهادی)  694606.1483  4.048984e+06  36.566485
# 21                       منبع آب  694201.9695  4.049010e+06  36.566808
# 22                       منبع آب  692904.3448  4.048445e+06  36.561972
# 23                       منبع آب  690702.4367  4.048344e+06  36.561508
# 24                        پایانه  691577.7646  4.047074e+06  36.549888
# 25                       دانشگاه  692944.0554  4.047732e+06  36.555544
# 26                  دانشگاه آزاد  692010.4316  4.049623e+06  36.572767
# 27                    اسکان موقت  690301.8602  4.047174e+06  36.551045
# 28                    اسکان موقت  692509.7822  4.048808e+06  36.565324
# 29           بیمارستان(پیشنهادی)  689236.0929  4.047212e+06  36.551604
# 30    مجموعه های آموزشی و پژوهشی  689773.2101  4.047972e+06  36.558340
# 31                  مجموعه ورزشی  690063.6845  4.049122e+06  36.568643
# 32                باغ گیاه شناسی  689035.1816  4.047994e+06  36.558685
# 33            کانون تجمع و امداد  690704.2154  4.045891e+06  36.539409
# 34         کانروانسرای حوض حضرتی  692711.6923  4.045384e+06  36.534438
# 35            کانون تجمع و امداد  692375.2757  4.046950e+06  36.548612
# 36            کانون تجمع و امداد  694308.1538  4.046617e+06  36.545224
# 37      بهداشتی-درمانی(پیشنهادی)  694103.4791  4.047709e+06  36.555100
# 38                    پایانه بار  694032.0414  4.052710e+06  36.600170
# 39               انبار و سردخانه  693888.4630  4.052246e+06  36.596019
# 40          میدان میوه و تره بار  694550.4295  4.052300e+06  36.596366
# 41                مجموعه گردشگری  698224.1922  4.049907e+06  36.574058
# 42                     بیمارستان  697548.9062  4.050948e+06  36.583577
# 43    پایانه مسافربری چند منظوره  697292.1941  4.051185e+06  36.585766
# 44                    پلیس راهور  694860.0000  4.053507e+06  36.607181
# 45                   جایگاه سوخت  698193.2535  4.050607e+06  36.580373
#
#     longitude
# 0   59.180496
# 1   59.190650
# 2   59.165887
# 3   59.189708
# 4   59.182618
# 5   59.188754
# 6   59.172805
# 7   59.165216
# 8   59.164721
# 9   59.215680
# 10  59.211734
# 11  59.216083
# 12  59.208602
# 13  59.204476
# 14  59.197516
# 15  59.203228
# 16  59.192716
# 17  59.188042
# 18  59.191274
# 19  59.191469
# 20  59.174736
# 21  59.170229
# 22  59.155596
# 23  59.130981
# 24  59.140441
# 25  59.155861
# 26  59.145907
# 27  59.126219
# 28  59.151280
# 29  59.114328
# 30  59.120513
# 31  59.124040
# 32  59.112276
# 33  59.130394
# 34  59.152679
# 35  59.149314
# 36  59.170812
# 37  59.168802
# 38  59.169264
# 39  59.167543
# 40  59.174952
# 41  59.215379
# 42  59.208104
# 43  59.205297
# 44  59.178717
# 45  59.215214
# Map has been saved as 'coordinates_map.html'. Open it in a web browser to view the locations.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd50dffaba98d5422fcc7e7bfa6d8b09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd50dffaba98d5422fcc7e7bfa6d8b09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd50dffaba98d5422fcc7e7bfa6d8b09 = L.map(
#                 &quot;map_cd50dffaba98d5422fcc7e7bfa6d8b09&quot;,
#                 {
#                     center: [36.5727262546705, 59.17283818502807],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13be45de557bdaccd2973672c1b6867f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cd50dffaba98d5422fcc7e7bfa6d8b09);
#
#
#             var marker_a905473af79ab01f9303d2536b7a6971 = L.marker(
#                 [36.60289311888347, 59.180495941769095],
#                 {}
#             ).addTo(map_cd50dffaba98d5422fcc7e7bfa6d8b09);
#
#
#         var popup_aefdbe69a2d906f86dd7f9164b04080b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b747b00d30010cc9003f1b0cda40d6e6 = $(`&lt;div id=&quot;html_b747b00d30010cc9003f1b0cda40d6e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;مجتمع آموزشی پرواز&lt;/div&gt;`)[0];
#                 popup_aefdbe69a2d906f86dd7f9164b04080b.setContent(html_b747b00d30010cc9003f1b0cda40d6e6);
#
#
#
#         marker_a905473af79ab01f9303d2536b7a6971.bindPopup(popup_aefdbe69a2d906f86dd7f9164b04080b)
#         ;
#
#
#
#
#             marker_a905473af79ab01f9303d2536b7a6971.bindTooltip(
#                 `&lt;div&gt;
#                      مجتمع آموزشی پرواز
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_360a093fa1bfbb27cdff7fc92b1ea096 = L.marker(
#                 [36.596962799467335, 59.190649996150455],
#                 {}
#             ).addTo(map_cd50dffaba98d5422fcc7e7bfa6d8b09);
#
#
#         var popup_f8a7259143c0f97d003cd64deabe18ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2464c4cb4caf8bee05fb77775d84c76 = $(`&lt;div id=&quot;html_d2464c4cb4caf8bee05fb77775d84c76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;مجتمع آموزشی پرواز(موجود)&lt;/div&gt;`)[0];
#                 popup_f8a7259143c0f97d003cd64deabe18ba.setContent(html_d2464c4cb4caf8bee05fb77775d84c76);
#
#
#
#         marker_360a093fa1bfbb27cdff7fc92b1ea096.bindPopup(popup_f8a7259143c0f97d003cd64deabe18ba)
#         ;
#
#
#
#
#             marker_360a093fa1bfbb27cdff7fc92b1ea096.bindTooltip(
#                 `&lt;div&gt;
#                      مجتمع آموزشی پرواز(موجود)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f95039ce00759edbcaeb27ce4a582300 = L.marker(
#                 [36.60371303738227, 59.16588677462151],
#                 {}
#             ).addTo(map_cd50dffaba98d5422fcc7e7bfa6d8b09);
#
#
#         var popup_24f59b85e0a8eeb149101392711de13d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da476cd67d5b644ab9a5f8a71d521997 = $(`&lt;div id=&quot;html_da476cd67d5b644ab9a5f8a71d521997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;دپوی قطار شهری&lt;/div&gt;`)[0];
#                 popup_24f59b85e0a8eeb149101392711de13d.setContent(html_da476cd67d5b644ab9a5f8a71d521997);
#
#
#
#         marker_f95039ce00759edbcaeb27ce4a582300.bindPopup(popup_24f59b85e0a8eeb149101392711de13d)
#         ;
#
#
#
#
#             marker_f95039ce00759edbcaeb27ce4a582300.bindTooltip(
#                 `&lt;div&gt;
#                      دپوی قطار شهری
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_42093ce1f169b505fb2fec3de4ccff6e = L.marker(
#                 [36.594907233203784, 59.18970790034049],
#                 {}
#             ).addTo(map_cd50dffaba98d5422fcc7e7bfa6d8b09);
#
#
#         var popup_f0abd6be42e29ab9c7539b85fd8b3df6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61da9ae19431c9a1f383e00b01bd55df = $(`&lt;div id=&quot;html_61da9ae19431c9a1f383e00b01bd55df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;مجموع ورزشی&lt;/div&gt;`)[0];
#                 popup_f0abd6be42e29ab9c7539b85fd8b3df6.setContent(html_61da9ae19431c9a1f383e00b01bd55df);
#
#
#
#         marker_42093ce1f169b505fb2fec3de4ccff6e.bindPopup(popup_f0abd6be42e29ab9c7539b85fd8b3df6)
#         ;
#
#
#
#
#             marker_42093ce1f169b505fb2fec3de4ccff6e.bindTooltip(
#                 `&lt;div&gt;

# %%
df
# Out:
#                         location            X             Y   latitude  \
# 0             مجتمع آموزشی پرواز  695029.9370  4.053035e+06  36.602893
# 1      مجتمع آموزشی پرواز(موجود)  695953.2804  4.052398e+06  36.596963
# 2                 دپوی قطار شهری  693721.0169  4.053096e+06  36.603713
# 3                    مجموع ورزشی  695874.1969  4.052168e+06  36.594907
# 4             کانون تجمع و امداد  695265.1365  4.051042e+06  36.584895
# 5                بیمارستان موجود  695828.3050  4.050435e+06  36.579305
# 6                        پست برق  694411.6908  4.049937e+06  36.575112
# 7             کانون تجمع و امداد  693738.8039  4.049644e+06  36.572605
# 8            آتش‌نشانی و کلانتری  693700.1689  4.049392e+06  36.570350
# 9                 ورودی اصلی شهر  698219.6850  4.051270e+06  36.586336
# 10  بخشداری،پاسگاه و پایگاه بسیج  697876.7896  4.050822e+06  36.582369
# 11                      نمایشگاه  698274.9886  4.050438e+06  36.578830
# 12                 مجموعه فرهنگی  697605.2455  4.050436e+06  36.578951
# 13               شورای حل اختلاف  697252.6305  4.049705e+06  36.572438
# 14                          مسجد  696628.1594  4.049759e+06  36.573057
# 15                          مسجد  697153.3668  4.049161e+06  36.567558
# 16                    سالن ورزشی  696207.7307  4.049349e+06  36.569448
# 17                          مسجد  695786.9164  4.049451e+06  36.570451
# 18                    آتش‌نشانی   696063.6492  4.050009e+06  36.575420
# 19                       کلانتری  696082.3877  4.049951e+06  36.574900
# 20                مصلی(پیشنهادی)  694606.1483  4.048984e+06  36.566485
# 21                       منبع آب  694201.9695  4.049010e+06  36.566808
# 22                       منبع آب  692904.3448  4.048445e+06  36.561972
# 23                       منبع آب  690702.4367  4.048344e+06  36.561508
# 24                        پایانه  691577.7646  4.047074e+06  36.549888
# 25                       دانشگاه  692944.0554  4.047732e+06  36.555544
# 26                  دانشگاه آزاد  692010.4316  4.049623e+06  36.572767
# 27                    اسکان موقت  690301.8602  4.047174e+06  36.551045
# 28                    اسکان موقت  692509.7822  4.048808e+06  36.565324
# 29           بیمارستان(پیشنهادی)  689236.0929  4.047212e+06  36.551604
# 30    مجموعه های آموزشی و پژوهشی  689773.2101  4.047972e+06  36.558340
# 31                  مجموعه ورزشی  690063.6845  4.049122e+06  36.568643
# 32                باغ گیاه شناسی  689035.1816  4.047994e+06  36.558685
# 33            کانون تجمع و امداد  690704.2154  4.045891e+06  36.539409
# 34         کانروانسرای حوض حضرتی  692711.6923  4.045384e+06  36.534438
# 35            کانون تجمع و امداد  692375.2757  4.046950e+06  36.548612
# 36            کانون تجمع و امداد  694308.1538  4.046617e+06  36.545224
# 37      بهداشتی-درمانی(پیشنهادی)  694103.4791  4.047709e+06  36.555100
# 38                    پایانه بار  694032.0414  4.052710e+06  36.600170
# 39               انبار و سردخانه  693888.4630  4.052246e+06  36.596019
# 40          میدان میوه و تره بار  694550.4295  4.052300e+06  36.596366
# 41                مجموعه گردشگری  698224.1922  4.049907e+06  36.574058
# 42                     بیمارستان  697548.9062  4.050948e+06  36.583577
# 43    پایانه مسافربری چند منظوره  697292.1941  4.051185e+06  36.585766
# 44                    پلیس راهور  694860.0000  4.053507e+06  36.607181
# 45                   جایگاه سوخت  698193.2535  4.050607e+06  36.580373
#
#     longitude
# 0   59.180496
# 1   59.190650
# 2   59.165887
# 3   59.189708
# 4   59.182618
# 5   59.188754
# 6   59.172805
# 7   59.165216
# 8   59.164721
# 9   59.215680
# 10  59.211734
# 11  59.216083
# 12  59.208602
# 13  59.204476
# 14  59.197516
# 15  59.203228
# 16  59.192716
# 17  59.188042
# 18  59.191274
# 19  59.191469
# 20  59.174736
# 21  59.170229
# 22  59.155596
# 23  59.130981
# 24  59.140441
# 25  59.155861
# 26  59.145907
# 27  59.126219
# 28  59.151280
# 29  59.114328
# 30  59.120513
# 31  59.124040
# 32  59.112276
# 33  59.130394
# 34  59.152679
# 35  59.149314
# 36  59.170812
# 37  59.168802
# 38  59.169264
# 39  59.167543
# 40  59.174952
# 41  59.215379
# 42  59.208104
# 43  59.205297
# 44  59.178717
# 45  59.215214

# %%
import pandas as pd

# Read the Excel file
#df = pd.read_excel('cordinates.xlsx')

# Function to format location name (replace spaces and special characters with underscores)
def format_location_name(location):
    return location.replace(' ', '_').replace('(', '_').replace(')', '')

# Filter out rows with NaN values in latitude or longitude
valid_df = df.dropna(subset=['latitude', 'longitude'])

# Create the points string in the desired format
points = "points=(\n"
for _, row in valid_df.iterrows():
    location = format_location_name(row['location'])
    points += f'    "{location} {row["longitude"]} {row["latitude"]}"\n'
points += ")"

# Print the result
print(points)

# Save the points string to a text file
with open('points_template.txt', 'w', encoding='utf-8') as f:
    f.write(points)
# Out:
# points=(
#     "مجتمع_آموزشی_پرواز 59.180495941769095 36.60289311888347"
#     "مجتمع_آموزشی_پرواز_موجود 59.190649996150455 36.596962799467335"
#     "دپوی_قطار_شهری 59.16588677462151 36.60371303738227"
#     "مجموع_ورزشی 59.18970790034049 36.594907233203784"
#     "کانون_تجمع_و_امداد 59.182617995012805 36.58489483680433"
#     "بیمارستان_موجود 59.188754163419155 36.5793051817252"
#     "پست_برق 59.17280548066051 36.57511197851596"
#     "کانون_تجمع_و_امداد 59.16521612137672 36.57260530095745"
#     "آتش‌نشانی_و_کلانتری 59.16472143833695 36.570350472402836"
#     "ورودی_اصلی_شهر 59.21567954156501 36.586336273727184"
#     "بخشداری،پاسگاه_و_پایگاه_بسیج 59.21173400480987 36.58236883464885"
#     "نمایشگاه 59.21608296761512 36.57883011043621"
#     "مجموعه_فرهنگی 59.2086018898944 36.578950554421134"
#     "شورای_حل_اختلاف 59.2044761122691 36.57243788545847"
#     "مسجد 59.19751564009223 36.57305713400965"
#     "مسجد 59.203228221245666 36.5675576246094"
#     "سالن_ورزشی 59.19271550830381 36.5694475223913"
#     "مسجد 59.18804169143005 36.57045085664034"
#     "آتش‌نشانی_ 59.19127437312351 36.575420172854834"
#     "کلانتری 59.19146905898714 36.57489977853123"
#     "مصلی_پیشنهادی 59.174736478431704 36.566484654091276"
#     "منبع_آب 59.17022942836029 36.56680771420772"
#     "منبع_آب 59.155595916378495 36.56197225316049"
#     "منبع_آب 59.1309814433911 36.56150829632208"
#     "پایانه 59.14044070632519 36.5498881289438"
#     "دانشگاه 59.15586091224401 36.55554371486386"
#     "دانشگاه_آزاد 59.145907032761606 36.57276676001967"
#     "اسکان_موقت 59.12621903925147 36.55104505492454"
#     "اسکان_موقت 59.1512804779774 36.565323611865026"
#     "بیمارستان_پیشنهادی 59.11432818185715 36.55160427146194"
#     "مجموعه_های_آموزشی_و_پژوهشی 59.12051269400536 36.5583404265341"
#     "مجموعه_ورزشی 59.124040161374154 36.568643223406774"
#     "باغ_گیاه_شناسی 59.11227648373316 36.5586846037151"
#     "کانون_تجمع_و_امداد 59.13039444441191 36.539409315756025"
#     "کانروانسرای_حوض_حضرتی 59.152679430893244 36.53443847643847"
#     "کانون_تجمع_و_امداد 59.149314471731394 36.548611510709264"
#     "کانون_تجمع_و_امداد 59.170811793926724 36.545224310364716"
#     "بهداشتی-درمانی_پیشنهادی 59.16880151239264 36.55509961502635"
#     "پایانه_بار 59.16926442917909 36.60016984891154"
#     "انبار_و_سردخانه 59.16754329469184 36.59601920219789"
#     "میدان_میوه_و_تره_بار 59.17495234863456 36.596366296469625"
#     "مجموعه_گردشگری 59.215378921055304 36.57405833492931"
#     "بیمارستان 59.20810409762026 36.58357692559965"
#     "پایانه_مسافربری_چند_منظوره 59.20529742095447 36.58576639069579"
#     "پلیس_راهور 59.17871689559913 36.60718066167165"
#     "جایگاه_سوخت 59.21521367308539 36.58037340548478"
# )

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import matplotlib.dates as mdates

# Set global font to Times New Roman
#plt.rcParams['font.family'] = 'Times New Roman'

# Directory containing time series files
directory = "./time_series"

# Function to parse date string to datetime
def parse_date(date_str):
    try:
        return datetime.strptime(date_str, '%Y%m%d')
    except ValueError as e:
        print(f"Error parsing date '{date_str}': {e}")
        raise

# Function to process a single file and create a plot
def process_file(file_path, filename):
    print(f"Processing file: {file_path}")
    try:
        # Read the file
        dates = []
        displacements = []
        with open(file_path, 'r') as f:
            lines = f.readlines()
            print(f"Read {len(lines)} lines from {filename}")
            # Start reading data after the last '#' line
            data_start = False
            for line in lines:
                if line.startswith('#'):
                    data_start = True
                    continue
                if data_start and line.strip():
                    try:
                        date_str, displacement = line.strip().split()
                        dates.append(parse_date(date_str))
                        displacements.append(float(displacement))
                    except ValueError as e:
                        print(f"Error parsing line '{line.strip()}' in {filename}: {e}")
                        continue

        if not dates:
            print(f"No valid data found in {filename}")
            return

        print(f"Parsed {len(dates)} data points from {filename}")

        # Convert dates to matplotlib date numbers
        dates_mpl = mdates.date2num(dates)
        X = np.array(dates_mpl).reshape(-1, 1)
        y = np.array(displacements)

        # Fit linear model
        model = LinearRegression().fit(X, y)
        slope = model.coef_[0]
        intercept = model.intercept_
        trendline = model.predict(X)
        annual_rate = int(round(slope * 365))  # mm/year, without decimals
        print(f"Linear model for {filename}: y = {slope:.2f}x + {intercept:.2f}, Annual Rate: {annual_rate} mm/year")

        # Create the plot
        plt.figure(figsize=(14, 4))
        # Scatter plot with black outline
        plt.scatter(dates, y, color='red', label='InSAR Data', alpha=0.8, s=80, edgecolors='black', linewidth=0.3)
        plt.plot(dates, trendline, color='black', linestyle='--', alpha=0.6, linewidth=2.5, label=f'Trendline: y = {slope:.2f}x + {intercept:.2f}\nAnnual Rate: {annual_rate} mm/year')

        # Set y-axis limits
        plt.ylim(-130, 30)

        # Labels and formatting
        plt.ylabel("Displacement (mm)", fontsize=14)
        plt.title(f"Subsidence", fontsize=15)
        plt.grid(True)
        # Place legend with trendline info
        plt.legend(fontsize=16, loc='best')

        # Rotate and bold x-axis tick labels
        plt.xticks(rotation=45)
        # for label in plt.gca().get_xticklabels():
        #     label.set_fontweight('bold')

        # Format x-axis to show only years
        plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
        plt.gca().xaxis.set_major_locator(mdates.YearLocator())

        # Adjust layout to prevent label cutoff
        plt.tight_layout()

        # Save the plot
        output_path = os.path.join(directory, f"{os.path.splitext(filename)[0]}.png")
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Saved plot to: {output_path}")
        plt.close()

    except Exception as e:
        print(f"Error processing {filename}: {e}")

# Check if directory exists
if not os.path.exists(directory):
    print(f"Directory '{directory}' does not exist")
else:
    print(f"Scanning directory: {directory}")
    # Iterate through all files in the time_series directory
    file_count = 0
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            file_count += 1
            file_path = os.path.join(directory, filename)
            print(f"Found file: {filename}")
            process_file(file_path, filename)
    if file_count == 0:
        print(f"No .txt files found in {directory}")

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from datetime import datetime
import matplotlib.dates as mdates

# Set global font to Times New Roman
#plt.rcParams['font.family'] = 'Times New Roman'

# Directory containing time series files
directory = "./time_series"

# Function to parse date string to datetime
def parse_date(date_str):
    try:
        return datetime.strptime(date_str, '%Y%m%d')
    except ValueError as e:
        print(f"Error parsing date '{date_str}': {e}")
        raise

# Function to process a single file and create a plot
def process_file(file_path, filename):
    print(f"Processing file: {file_path}")
    try:
        # Read the file
        dates = []
        displacements = []
        with open(file_path, 'r') as f:
            lines = f.readlines()
            print(f"Read {len(lines)} lines from {filename}")
            # Start reading data after the last '#' line
            data_start = False
            for line in lines:
                if line.startswith('#'):
                    data_start = True
                    continue
                if data_start and line.strip():
                    try:
                        date_str, displacement = line.strip().split()
                        dates.append(parse_date(date_str))
                        displacements.append(float(displacement))
                    except ValueError as e:
                        print(f"Error parsing line '{line.strip()}' in {filename}: {e}")
                        continue

        if not dates:
            print(f"No valid data found in {filename}")
            return

        print(f"Parsed {len(dates)} data points from {filename}")

        # Convert dates to matplotlib date numbers
        dates_mpl = mdates.date2num(dates)
        X = np.array(dates_mpl).reshape(-1, 1)
        y = np.array(displacements)

        # Fit linear model
        model = LinearRegression().fit(X, y)
        slope = model.coef_[0]
        intercept = model.intercept_
        trendline = model.predict(X)
        annual_rate = int(round(slope * 365))  # mm/year, without decimals
        print(f"Linear model for {filename}: y = {slope:.2f}x + {intercept:.2f}, Annual Rate: {annual_rate} mm/year")

        # Create the plot
        plt.figure(figsize=(14, 4))
        # Scatter plot with black outline
        plt.scatter(dates, y, color='red', label='InSAR Data', alpha=0.8, s=80, edgecolors='black', linewidth=0.3)
        plt.plot(dates, trendline, color='black', linestyle='--', alpha=0.6, linewidth=2.5, label=f'Trendline: y = {slope:.2f}x + {intercept:.2f}\nAnnual Rate: {annual_rate} mm/year')
        # Add bold y=0 baseline
        plt.axhline(y=0, color='black', linewidth=1, alpha=0.8 ) #label='Baseline (y=0)')

        # Set y-axis limits
        plt.ylim(-130, 30)

        # Labels and formatting
        plt.ylabel("Displacement (mm)", fontsize=14)
        plt.title(f"Subsidence", fontsize=15)
        plt.grid(True)
        # Place legend with trendline info
        plt.legend(fontsize=16, loc='best')

        # Rotate and bold x-axis tick labels
        plt.xticks(rotation=45)
        # for label in plt.gca().get_xticklabels():
        #     label.set_fontweight('bold')

        # Format x-axis to show only years
        plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
        plt.gca().xaxis.set_major_locator(mdates.YearLocator())

        # Adjust layout to prevent label cutoff
        plt.tight_layout()

        # Save the plot
        output_path = os.path.join(directory, f"{os.path.splitext(filename)[0]}.png")
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        print(f"Saved plot to: {output_path}")
        plt.close()

    except Exception as e:
        print(f"Error processing {filename}: {e}")

# Check if directory exists
if not os.path.exists(directory):
    print(f"Directory '{directory}' does not exist")
else:
    print(f"Scanning directory: {directory}")
    # Iterate through all files in the time_series directory
    file_count = 0
    for filename in os.listdir(directory):
        if filename.endswith('.txt'):
            file_count += 1
            file_path = os.path.join(directory, filename)
            print(f"Found file: {filename}")
            process_file(file_path, filename)
    if file_count == 0:
        print(f"No .txt files found in {directory}")
# Out:
# Scanning directory: ./time_series
# Found file: مجتمع_آموزشی_پرواز.txt
# Processing file: ./time_series/مجتمع_آموزشی_پرواز.txt
# Read 239 lines from مجتمع_آموزشی_پرواز.txt
# Parsed 231 data points from مجتمع_آموزشی_پرواز.txt
# Linear model for مجتمع_آموزشی_پرواز.txt: y = -0.01x + 247.66, Annual Rate: -5 mm/year
# Saved plot to: ./time_series/مجتمع_آموزشی_پرواز.png
# Found file: مجتمع_آموزشی_پرواز_موجود.txt
# Processing file: ./time_series/مجتمع_آموزشی_پرواز_موجود.txt
# Read 239 lines from مجتمع_آموزشی_پرواز_موجود.txt
# Parsed 231 data points from مجتمع_آموزشی_پرواز_موجود.txt
# Linear model for مجتمع_آموزشی_پرواز_موجود.txt: y = -0.00x + 78.55, Annual Rate: -2 mm/year
# Saved plot to: ./time_series/مجتمع_آموزشی_پرواز_موجود.png
# Found file: مجموع_ورزشی.txt
# Processing file: ./time_series/مجموع_ورزشی.txt
# Read 239 lines from مجموع_ورزشی.txt
# Parsed 231 data points from مجموع_ورزشی.txt
# Linear model for مجموع_ورزشی.txt: y = 0.00x + -13.09, Annual Rate: 0 mm/year
# Saved plot to: ./time_series/مجموع_ورزشی.png
# Found file: مجموعه_فرهنگی.txt
# Processing file: ./time_series/مجموعه_فرهنگی.txt
# Read 239 lines from مجموعه_فرهنگی.txt
# Parsed 231 data points from مجموعه_فرهنگی.txt
# Linear model for مجموعه_فرهنگی.txt: y = -0.01x + 105.44, Annual Rate: -2 mm/year
# Saved plot to: ./time_series/مجموعه_فرهنگی.png
# Found file: مجموعه_های_آموزشی_و_پژوهشی.txt
# Processing file: ./time_series/مجموعه_های_آموزشی_و_پژوهشی.txt
# Read 239 lines from مجموعه_های_آموزشی_و_پژوهشی.txt
# Parsed 231 data points from مجموعه_های_آموزشی_و_پژوهشی.txt
# Linear model for مجموعه_های_آموزشی_و_پژوهشی.txt: y = -0.01x + 96.07, Annual Rate: -2 mm/year
# Saved plot to: ./time_series/مجموعه_های_آموزشی_و_پژوهشی.png
# Found file: مجموعه_ورزشی.txt
# Processing file: ./time_series/مجموعه_ورزشی.txt
# Read 239 lines from مجموعه_ورزشی.txt
# Parsed 231 data points from مجموعه_ورزشی.txt
# Linear model for مجموعه_ورزشی.txt: y = 0.00x + -66.27, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/مجموعه_ورزشی.png
# Found file: مجموعه_گردشگری.txt
# Processing file: ./time_series/مجموعه_گردشگری.txt
# Read 239 lines from مجموعه_گردشگری.txt
# Parsed 231 data points from مجموعه_گردشگری.txt
# Linear model for مجموعه_گردشگری.txt: y = -0.01x + 207.22, Annual Rate: -5 mm/year
# Saved plot to: ./time_series/مجموعه_گردشگری.png
# Found file: مسجد.txt
# Processing file: ./time_series/مسجد.txt
# Read 239 lines from مسجد.txt
# Parsed 231 data points from مسجد.txt
# Linear model for مسجد.txt: y = 0.01x + -103.62, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/مسجد.png
# Found file: مصلی_پیشنهادی.txt
# Processing file: ./time_series/مصلی_پیشنهادی.txt
# Read 239 lines from مصلی_پیشنهادی.txt
# Parsed 231 data points from مصلی_پیشنهادی.txt
# Linear model for مصلی_پیشنهادی.txt: y = 0.01x + -92.51, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/مصلی_پیشنهادی.png
# Found file: منبع_آب.txt
# Processing file: ./time_series/منبع_آب.txt
# Read 239 lines from منبع_آب.txt
# Parsed 231 data points from منبع_آب.txt
# Linear model for منبع_آب.txt: y = 0.00x + -43.76, Annual Rate: 1 mm/year
# Saved plot to: ./time_series/منبع_آب.png
# Found file: میدان_میوه_و_تره_بار.txt
# Processing file: ./time_series/میدان_میوه_و_تره_بار.txt
# Read 239 lines from میدان_میوه_و_تره_بار.txt
# Parsed 231 data points from میدان_میوه_و_تره_بار.txt
# Linear model for میدان_میوه_و_تره_بار.txt: y = 0.00x + -55.60, Annual Rate: 1 mm/year
# Saved plot to: ./time_series/میدان_میوه_و_تره_بار.png
# Found file: نمایشگاه.txt
# Processing file: ./time_series/نمایشگاه.txt
# Read 239 lines from نمایشگاه.txt
# Parsed 231 data points from نمایشگاه.txt
# Linear model for نمایشگاه.txt: y = -0.02x + 405.26, Annual Rate: -9 mm/year
# Saved plot to: ./time_series/نمایشگاه.png
# Found file: ورودی_اصلی_شهر.txt
# Processing file: ./time_series/ورودی_اصلی_شهر.txt
# Read 239 lines from ورودی_اصلی_شهر.txt
# Parsed 231 data points from ورودی_اصلی_شهر.txt
# Linear model for ورودی_اصلی_شهر.txt: y = -0.04x + 602.05, Annual Rate: -13 mm/year
# Saved plot to: ./time_series/ورودی_اصلی_شهر.png
# Found file: پایانه.txt
# Processing file: ./time_series/پایانه.txt
# Read 239 lines from پایانه.txt
# Parsed 231 data points from پایانه.txt
# Linear model for پایانه.txt: y = 0.01x + -92.43, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/پایانه.png
# Found file: پایانه_بار.txt
# Processing file: ./time_series/پایانه_بار.txt
# Read 239 lines from پایانه_بار.txt
# Parsed 231 data points from پایانه_بار.txt
# Linear model for پایانه_بار.txt: y = 0.00x + -13.38, Annual Rate: 0 mm/year
# Saved plot to: ./time_series/پایانه_بار.png
# Found file: پایانه_مسافربری_چند_منظوره.txt
# Processing file: ./time_series/پایانه_مسافربری_چند_منظوره.txt
# Read 239 lines from پایانه_مسافربری_چند_منظوره.txt
# Parsed 231 data points from پایانه_مسافربری_چند_منظوره.txt
# Linear model for پایانه_مسافربری_چند_منظوره.txt: y = -0.01x + 186.30, Annual Rate: -4 mm/year
# Saved plot to: ./time_series/پایانه_مسافربری_چند_منظوره.png
# Found file: پست_برق.txt
# Processing file: ./time_series/پست_برق.txt
# Read 239 lines from پست_برق.txt
# Parsed 231 data points from پست_برق.txt
# Linear model for پست_برق.txt: y = 0.01x + -83.20, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/پست_برق.png
# Found file: پلیس_راهور.txt
# Processing file: ./time_series/پلیس_راهور.txt
# Read 239 lines from پلیس_راهور.txt
# Parsed 231 data points from پلیس_راهور.txt
# Linear model for پلیس_راهور.txt: y = -0.02x + 313.58, Annual Rate: -7 mm/year
# Saved plot to: ./time_series/پلیس_راهور.png
# Found file: کانروانسرای_حوض_حضرتی.txt
# Processing file: ./time_series/کانروانسرای_حوض_حضرتی.txt
# Read 239 lines from کانروانسرای_حوض_حضرتی.txt
# Parsed 231 data points from کانروانسرای_حوض_حضرتی.txt
# Linear model for کانروانسرای_حوض_حضرتی.txt: y = 0.01x + -105.31, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/کانروانسرای_حوض_حضرتی.png
# Found file: کانون_تجمع_و_امداد.txt
# Processing file: ./time_series/کانون_تجمع_و_امداد.txt
# Read 239 lines from کانون_تجمع_و_امداد.txt
# Parsed 231 data points from کانون_تجمع_و_امداد.txt
# Linear model for کانون_تجمع_و_امداد.txt: y = 0.01x + -94.44, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/کانون_تجمع_و_امداد.png
# Found file: کلانتری.txt
# Processing file: ./time_series/کلانتری.txt
# Read 239 lines from کلانتری.txt
# Parsed 231 data points from کلانتری.txt
# Linear model for کلانتری.txt: y = 0.01x + -87.97, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/کلانتری.png
# Found file: آتش‌نشانی_.txt
# Processing file: ./time_series/آتش‌نشانی_.txt
# Read 239 lines from آتش‌نشانی_.txt
# Parsed 231 data points from آتش‌نشانی_.txt
# Linear model for آتش‌نشانی_.txt: y = 0.01x + -87.97, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/آتش‌نشانی_.png
# Found file: آتش‌نشانی_و_کلانتری.txt
# Processing file: ./time_series/آتش‌نشانی_و_کلانتری.txt
# Read 239 lines from آتش‌نشانی_و_کلانتری.txt
# Parsed 231 data points from آتش‌نشانی_و_کلانتری.txt
# Linear model for آتش‌نشانی_و_کلانتری.txt: y = 0.01x + -92.04, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/آتش‌نشانی_و_کلانتری.png
# Found file: اسکان_موقت.txt
# Processing file: ./time_series/اسکان_موقت.txt
# Read 239 lines from اسکان_موقت.txt
# Parsed 231 data points from اسکان_موقت.txt
# Linear model for اسکان_موقت.txt: y = 0.01x + -105.11, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/اسکان_موقت.png
# Found file: انبار_و_سردخانه.txt
# Processing file: ./time_series/انبار_و_سردخانه.txt
# Read 239 lines from انبار_و_سردخانه.txt
# Parsed 231 data points from انبار_و_سردخانه.txt
# Linear model for انبار_و_سردخانه.txt: y = 0.00x + -64.87, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/انبار_و_سردخانه.png
# Found file: باغ_گیاه_شناسی.txt
# Processing file: ./time_series/باغ_گیاه_شناسی.txt
# Read 239 lines from باغ_گیاه_شناسی.txt
# Parsed 231 data points from باغ_گیاه_شناسی.txt
# Linear model for باغ_گیاه_شناسی.txt: y = -0.00x + 18.88, Annual Rate: 0 mm/year
# Saved plot to: ./time_series/باغ_گیاه_شناسی.png
# Found file: بخشداری،پاسگاه_و_پایگاه_بسیج.txt
# Processing file: ./time_series/بخشداری،پاسگاه_و_پایگاه_بسیج.txt
# Read 239 lines from بخشداری،پاسگاه_و_پایگاه_بسیج.txt
# Parsed 231 data points from بخشداری،پاسگاه_و_پایگاه_بسیج.txt
# Linear model for بخشداری،پاسگاه_و_پایگاه_بسیج.txt: y = -0.02x + 286.27, Annual Rate: -6 mm/year
# Saved plot to: ./time_series/بخشداری،پاسگاه_و_پایگاه_بسیج.png
# Found file: بهداشتی-درمانی_پیشنهادی.txt
# Processing file: ./time_series/بهداشتی-درمانی_پیشنهادی.txt
# Read 239 lines from بهداشتی-درمانی_پیشنهادی.txt
# Parsed 231 data points from بهداشتی-درمانی_پیشنهادی.txt
# Linear model for بهداشتی-درمانی_پیشنهادی.txt: y = 0.01x + -95.21, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/بهداشتی-درمانی_پیشنهادی.png
# Found file: بیمارستان.txt
# Processing file: ./time_series/بیمارستان.txt
# Read 239 lines from بیمارستان.txt
# Parsed 231 data points from بیمارستان.txt
# Linear model for بیمارستان.txt: y = -0.01x + 246.42, Annual Rate: -5 mm/year
# Saved plot to: ./time_series/بیمارستان.png
# Found file: بیمارستان_موجود.txt
# Processing file: ./time_series/بیمارستان_موجود.txt
# Read 239 lines from بیمارستان_موجود.txt
# Parsed 231 data points from بیمارستان_موجود.txt
# Linear model for بیمارستان_موجود.txt: y = 0.00x + -75.14, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/بیمارستان_موجود.png
# Found file: بیمارستان_پیشنهادی.txt
# Processing file: ./time_series/بیمارستان_پیشنهادی.txt
# Read 239 lines from بیمارستان_پیشنهادی.txt
# Parsed 231 data points from بیمارستان_پیشنهادی.txt
# Linear model for بیمارستان_پیشنهادی.txt: y = -0.01x + 127.09, Annual Rate: -3 mm/year
# Saved plot to: ./time_series/بیمارستان_پیشنهادی.png
# Found file: جایگاه_سوخت.txt
# Processing file: ./time_series/جایگاه_سوخت.txt
# Read 239 lines from جایگاه_سوخت.txt
# Parsed 231 data points from جایگاه_سوخت.txt
# Linear model for جایگاه_سوخت.txt: y = -0.02x + 373.53, Annual Rate: -8 mm/year
# Saved plot to: ./time_series/جایگاه_سوخت.png
# Found file: دانشگاه.txt
# Processing file: ./time_series/دانشگاه.txt
# Read 239 lines from دانشگاه.txt
# Parsed 231 data points from دانشگاه.txt
# Linear model for دانشگاه.txt: y = 0.01x + -114.50, Annual Rate: 3 mm/year
# Saved plot to: ./time_series/دانشگاه.png
# Found file: دانشگاه_آزاد.txt
# Processing file: ./time_series/دانشگاه_آزاد.txt
# Read 239 lines from دانشگاه_آزاد.txt
# Parsed 231 data points from دانشگاه_آزاد.txt
# Linear model for دانشگاه_آزاد.txt: y = 0.01x + -90.32, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/دانشگاه_آزاد.png
# Found file: دپوی_قطار_شهری.txt
# Processing file: ./time_series/دپوی_قطار_شهری.txt
# Read 239 lines from دپوی_قطار_شهری.txt
# Parsed 231 data points from دپوی_قطار_شهری.txt
# Linear model for دپوی_قطار_شهری.txt: y = -0.00x + 38.57, Annual Rate: -1 mm/year
# Saved plot to: ./time_series/دپوی_قطار_شهری.png
# Found file: سالن_ورزشی.txt
# Processing file: ./time_series/سالن_ورزشی.txt
# Read 239 lines from سالن_ورزشی.txt
# Parsed 231 data points from سالن_ورزشی.txt
# Linear model for سالن_ورزشی.txt: y = 0.01x + -103.42, Annual Rate: 2 mm/year
# Saved plot to: ./time_series/سالن_ورزشی.png
# Found file: شورای_حل_اختلاف.txt
# Processing file: ./time_series/شورای_حل_اختلاف.txt
# Read 239 lines from شورای_حل_اختلاف.txt
# Parsed 231 data points from شورای_حل_اختلاف.txt
# Linear model for شورای_حل_اختلاف.txt: y = 0.00x + -59.92, Annual Rate: 1 mm/year
# Saved plot to: ./time_series/شورای_حل_اختلاف.png

# %%
import pandas as pd
import folium
from pyproj import Transformer
import folium.plugins

# Read the Excel file
df = pd.read_excel('cordinates.xlsx')

# Create a Transformer for UTM Zone 40 North to WGS84 (lat/lon)
transformer = Transformer.from_crs("EPSG:32640", "EPSG:4326", always_xy=True)

# Function to convert UTM to decimal degrees
def utm_to_latlon(row):
    if pd.isna(row['X']) or pd.isna(row['Y']):  # Handle NaN values
        return pd.Series([None, None], index=['latitude', 'longitude'])
    lon, lat = transformer.transform(row['X'], row['Y'])
    return pd.Series([lat, lon], index=['latitude', 'longitude'])

# Apply conversion to each row
df[['latitude', 'longitude']] = df.apply(utm_to_latlon, axis=1)

# Create a Folium map centered on the average of valid coordinates
valid_coords = df.dropna(subset=['latitude', 'longitude'])
center_lat = valid_coords['latitude'].mean()
center_lon = valid_coords['longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)

# Add markers for each valid location
for _, row in valid_coords.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['location'],
        tooltip=row['location']
    ).add_to(m)

# Add measurement tool
folium.plugins.MeasureControl(
    position='topright',
    primary_length_unit='meters',
    secondary_length_unit='kilometers',
    primary_area_unit='sqmeters',
    secondary_area_unit='hectares'
).add_to(m)

# Save the map to an HTML file
m.save('coordinates_map.html')

# Print the DataFrame to verify coordinates
print(df)

# Inform user about the map
print("Map with measurement tool has been saved as 'coordinates_map.html'. Open it in a web browser to view the locations.")

# %%
import pandas as pd
import folium
from pyproj import Transformer
import folium.plugins

# Read the Excel file
df = pd.read_excel('cordinates.xlsx')

# Create a Transformer for UTM Zone 40 North to WGS84 (lat/lon)
transformer = Transformer.from_crs("EPSG:32640", "EPSG:4326", always_xy=True)

# Function to convert UTM to decimal degrees
def utm_to_latlon(row):
    if pd.isna(row['X']) or pd.isna(row['Y']):  # Handle NaN values
        return pd.Series([None, None], index=['latitude', 'longitude'])
    lon, lat = transformer.transform(row['X'], row['Y'])
    return pd.Series([lat, lon], index=['latitude', 'longitude'])

# Apply conversion to each row
df[['latitude', 'longitude']] = df.apply(utm_to_latlon, axis=1)

# Create a Folium map centered on the average of valid coordinates
valid_coords = df.dropna(subset=['latitude', 'longitude'])
center_lat = valid_coords['latitude'].mean()
center_lon = valid_coords['longitude'].mean()
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)

# Add markers for each valid location
for _, row in valid_coords.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['location'],
        tooltip=row['location']
    ).add_to(m)

# Add measurement tool
folium.plugins.MeasureControl(
    position='topright',
    primary_length_unit='meters',
    secondary_length_unit='kilometers',
    primary_area_unit='sqmeters',
    secondary_area_unit='hectares'
).add_to(m)

# Save the map to an HTML file
m.save('coordinates_map.html')

# Print the DataFrame to verify coordinates
print(df)

# Inform user about the map
print("Map with measurement tool has been saved as 'coordinates_map.html'. Open it in a web browser to view the locations.")
